# %% [markdown]
# #Load Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt 
import warnings
warnings.filterwarnings("ignore")
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay,classification_report

from sklearn.metrics import roc_auc_score,f1_score,recall_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from sklearn.svm import SVC
from sklearn import tree
import graphviz

import xgboost as xgb
import lightgbm as lgb

from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE

# Splitting data into training and testing
from sklearn.model_selection import train_test_split

# Internal ipython tool for setting figure size
from IPython.core.pylabtools import figsize

# No warnings about setting value on copy of slice
pd.options.mode.chained_assignment = None

# Display up to 60 columns of a dataframe
pd.set_option('display.max_columns', 60)

#Set Seaborn Theme
custom_params = {"axes.spines.right": False, "axes.spines.top": False}
sns.set_theme(style="ticks", rc=custom_params)
sns.set_style("darkgrid")
#Setting to display Pipeline
from sklearn import set_config
set_config(display="diagram")
sns.set(rc={'figure.figsize':(10,4)})

# %%
# Read in data into a dataframe 
data = pd.read_csv("Customer-Value-Analysis.csv")
# Display top of dataframe
data.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income Location Code  \
# 0           2/24/11         Employed      F   56274      Suburban
# 1           1/31/11       Unemployed      F       0      Suburban
# 2           2/19/11         Employed      F   48767      Suburban
# 3           1/20/11       Unemployed      M       0      Suburban
# 4            2/3/11         Employed      M   43836         Rural
#
#   Marital Status  Monthly Premium Auto  Months Since Last Claim  \
# 0        Married                    69                       32
# 1         Single                    94                       13
# 2        Married                   108                       18
# 3        Married                   106                       18
# 4         Single                    73                       12
#
#    Months Since Policy Inception  Number of Open Complaints  \
# 0                              5                          0
# 1                             42                          0
# 2                             38                          0
# 3                             65                          0
# 4                             44                          0
#
#    Number of Policies     Policy Type        Policy Renew Offer Type  \
# 0                   1  Corporate Auto  Corporate L3           Offer1
# 1                   8   Personal Auto   Personal L3           Offer3
# 2                   2   Personal Auto   Personal L3           Offer1
# 3                   7  Corporate Auto  Corporate L2           Offer1
# 4                   1   Personal Auto   Personal L1           Offer1
#
#   Sales Channel  Total Claim Amount  Vehicle Class Vehicle Size
# 0         Agent          384.811147   Two-Door Car      Medsize
# 1         Agent         1131.464935  Four-Door Car      Medsize
# 2         Agent          566.472247   Two-Door Car      Medsize
# 3   Call Center          529.881344            SUV      Medsize
# 4         Agent          138.130879  Four-Door Car      Medsize

# %%
# See the column data types and non-missing values
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
#  12  Monthly Premium Auto           9134 non-null   int64
#  13  Months Since Last Claim        9134 non-null   int64
#  14  Months Since Policy Inception  9134 non-null   int64
#  15  Number of Open Complaints      9134 non-null   int64
#  16  Number of Policies             9134 non-null   int64
#  17  Policy Type                    9134 non-null   object
#  18  Policy                         9134 non-null   object
#  19  Renew Offer Type               9134 non-null   object
#  20  Sales Channel                  9134 non-null   object
#  21  Total Claim Amount             9134 non-null   float64
#  22  Vehicle Class                  9134 non-null   object
#  23  Vehicle Size                   9134 non-null   object
# dtypes: float64(2), int64(6), object(16)
# memory usage: 1.7+ MB

# %%
#check for duplicates
data.duplicated().any()
# Out:
# False

# %%
data.shape
# Out:
# (9134, 24)

# %%
# Statistics for each column
data.describe()
# Out:
#        Customer Lifetime Value        Income  Monthly Premium Auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        Months Since Last Claim  Months Since Policy Inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# 25%                   6.000000                      24.000000
# 50%                  14.000000                      48.000000
# 75%                  23.000000                      71.000000
# max                  35.000000                      99.000000
#
#        Number of Open Complaints  Number of Policies  Total Claim Amount
# count                9134.000000         9134.000000         9134.000000
# mean                    0.384388            2.966170          434.088794
# std                     0.910384            2.390182          290.500092
# min                     0.000000            1.000000            0.099007
# 25%                     0.000000            1.000000          272.258244
# 50%                     0.000000            2.000000          383.945434
# 75%                     0.000000            4.000000          547.514839
# max                     5.000000            9.000000         2893.239678

# %% [markdown]
# #Missing Values

# %%
# Function to calculate missing values by column
def missing_values_table(df):
        # Total missing values
        mis_val = df.isnull().sum()
        
        # Percentage of missing values
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        
        # Make a table with the results
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        
        # Rename the columns
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        
        # Sort the table by percentage of missing descending
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        
        # Print some summary information
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        
        # Return the dataframe with missing information
        return mis_val_table_ren_columns

# %%
missing_values_table(data)
# Out:
# Your selected dataframe has 24 columns.
# There are 0 columns that have missing values.
# Empty DataFrame
# Columns: [Missing Values, % of Total Values]
# Index: []

# %% [markdown]
# #Exploratory Data Analysis (EDA)

# %%
# round up to numerical
data['Customer Lifetime Value'] = data['Customer Lifetime Value'].apply(np.ceil)
data['Total Claim Amount'] = data['Total Claim Amount'].apply(np.ceil)

# %%
# datetime 
# split them into year date and month
data['Effective To Date'] = pd.to_datetime(data['Effective To Date'])

data['Year'] = data['Effective To Date'].dt.year
data['Month'] = data['Effective To Date'].dt.month
data['Day'] = data['Effective To Date'].dt.day

# %%
data.drop(["Customer","Effective To Date"],axis=1,inplace=True)
#data.describe(include="object")

# %%
# Univariate Analysis 
sns.countplot(data['Response'])

# %% [markdown]
# *   Responses are heavily imbalanced . A large number of customers did not churn .

# %%
#categiorical variables plotted
for col in data:
    if data[col].dtype == pd.CategoricalDtype:
        plt.figure(figsize=(16,8))
        sns.countplot(x=col,
                      data=data,
                      palette='flare')

# %%
# removing outliers
# Calculate first and third quartile
first_quartile = data['Total Claim Amount'].describe()['25%']
third_quartile = data['Total Claim Amount'].describe()['75%']

# Interquartile range
iqr = third_quartile - first_quartile

# Remove outliers
data = data[(data['Total Claim Amount'] > (first_quartile - 3 * iqr)) &
            (data['Total Claim Amount'] < (third_quartile + 3 * iqr))]

# %%
# Histogram Plot of Total Claim Amount
figsize(8, 8)
plt.hist(data['Total Claim Amount'].dropna(), bins = 20, edgecolor = 'black');
plt.xlabel('Total Claim Amount'); 
plt.ylabel('Count'); plt.title('Total Claim Amount Distribution');

# %%
# removing outliers
# Calculate first and third quartile
first_quartile = data['Customer Lifetime Value'].describe()['25%']
third_quartile = data['Customer Lifetime Value'].describe()['75%']

# Interquartile range
iqr = third_quartile - first_quartile

# Remove outliers
data = data[(data['Customer Lifetime Value'] > (first_quartile - 3 * iqr)) &
            (data['Customer Lifetime Value'] < (third_quartile + 3 * iqr))]

# %%
# Histogram Plot of Customer Lifetime Value
figsize(8, 8)
plt.hist(data['Customer Lifetime Value'].dropna(), bins = 20, edgecolor = 'black');
plt.xlabel('Customer Lifetime Value'); 
plt.ylabel('Count'); plt.title('Customer Lifetime Value Distribution');

# %%
for col in data:
    if data[col].dtype == np.float64:
        plt.figure(figsize=(16,8))
        sns.FacetGrid(data,
                      hue="Response",
                      size=8).map(
                          sns.distplot,col
                      ).add_legend()

# %%
# removing outliers
# Calculate first and third quartile
first_quartile = data['Income'].describe()['25%']
third_quartile = data['Income'].describe()['75%']

# Interquartile range
iqr = third_quartile - first_quartile

# Remove outliers
data = data[(data['Income'] > (first_quartile - 3 * iqr)) &
            (data['Income'] < (third_quartile + 3 * iqr))]

# %%
# Histogram Plot of Income
figsize(8, 8)
plt.hist(data['Income'].dropna(), bins = 20, edgecolor = 'black');
plt.xlabel('Income'); 
plt.ylabel('Count'); plt.title('Income');

# %% [markdown]
# This is suspicious . Over 2000+ respondents have an income of 0.
# This might mean they did not provide this information or they were taken out intentionally.

# %%
data['Income'].describe()
# Out:
# count     8650.000000
# mean     37926.516532
# std      30396.697764
# min          0.000000
# 25%          0.000000
# 50%      34388.000000
# 75%      62464.000000
# max      99981.000000
# Name: Income, dtype: float64

# %%
# converting Response into 1 and 0 
data['Response'] = pd.factorize(data['Response'])[0]

# %%
anom = data[data['Income'] == 0]
non_anom = data[data['Income'] != 0]
print('The non-anomalies churn  %0.2f%% ' % (100 * non_anom['Response'].mean()))
print('The anomalies churn  %0.2f%% ' % (100 * anom['Response'].mean()))
print('There are %d anomalous income' % len(anom))
# Out:
# The non-anomalies churn  16.28%
# The anomalies churn  9.15%
# There are 2164 anomalous income

# %% [markdown]
# Well that is extremely interesting! It turns out that the anomalies have a lower rate of churn.
#
# Handling the anomalies depends on the exact situation, with no set rules. One of the safest approaches is just to set the anomalies to a missing value and then have them filled in (using Imputation) before machine learning. In this case, since all the anomalies have the exact same value, we want to fill them in with the same value in case all of these data share something in common. The anomalous values seem to have some importance, so we want to tell the machine learning model if we did in fact fill in these values. As a solution, we will fill in the anomalous values with not a number (np.nan) and then create a new boolean column indicating whether or not the value was anomalous.

# %%
# Create an anomalous flag column
data['Income_Anom'] = data["Income"] == 0

# Replace the anomalous values with nan
data['Income'].replace({0: np.nan}, inplace = True)

data['Income'].plot.hist(title = 'Income Histogram');
plt.xlabel('Income');

# %% [markdown]
# The distribution looks to be much more in line with what we would expect, and we also have created a new column to tell the model that these values were originally anomalous (becuase we will have to fill in the nans with some value, probably the median of the column).

# %%
# removing outliers
# Calculate first and third quartile
first_quartile = data['Monthly Premium Auto'].describe()['25%']
third_quartile = data['Monthly Premium Auto'].describe()['75%']

# Interquartile range
iqr = third_quartile - first_quartile

# Remove outliers
data = data[(data['Monthly Premium Auto'] > (first_quartile - 3 * iqr)) &
            (data['Monthly Premium Auto'] < (third_quartile + 3 * iqr))]

# %%
# Histogram Plot of Monthly Premium Auto
figsize(8, 8)
plt.hist(data['Monthly Premium Auto'].dropna(), bins = 20, edgecolor = 'black');
plt.xlabel('Monthly Premium Auto'); 
plt.ylabel('Count'); plt.title('Monthly Premium Auto');

# %%
for col in data:
    if data[col].dtype == np.int64:
        plt.figure(figsize=(16,8))
        sns.FacetGrid(data,
                      hue="Response",
                      size=8).map(
                          sns.distplot,col
                      ).add_legend()

# %%
# Months Since Policy Inception into a separate dataframe
pol_data = data[['Response', 'Months Since Policy Inception']]

# Bin the  data
pol_data['Pol'] = pd.cut(pol_data['Months Since Policy Inception'], bins = np.linspace(0, 120, num = 4))
pol_data.head(10)
# Out:
#     Response  Months Since Policy Inception            Pol
# 0          0                              5    (0.0, 40.0]
# 1          0                             42   (40.0, 80.0]
# 2          0                             38    (0.0, 40.0]
# 3          0                             65   (40.0, 80.0]
# 4          0                             44   (40.0, 80.0]
# 5          1                             94  (80.0, 120.0]
# 6          1                             13    (0.0, 40.0]
# 7          0                             68   (40.0, 80.0]
# 9          0                              7    (0.0, 40.0]
# 10         0                              5    (0.0, 40.0]

# %%
# Group by the bin and calculate averages
pol_groups  = pol_data.groupby('Pol').mean()
pol_groups
# Out:
#                Response  Months Since Policy Inception
# Pol
# (0.0, 40.0]    0.133071                      20.806569
# (40.0, 80.0]   0.161487                      60.112375
# (80.0, 120.0]  0.119557                      89.710701

# %%
plt.figure(figsize = (4, 4))

# Graph the age bins and the average of the target as a bar plot
plt.bar(pol_groups.index.astype(str), 100 * pol_groups['Response'])

# Plot labeling
plt.xticks(rotation = 75); plt.xlabel('Months'); plt.ylabel('Likelihood to churn (%)')
plt.title('Likelihood to churn based on months since policy inception');

# %%
for col in data:
    if data[col].dtype == pd.CategoricalDtype:
        plt.figure(figsize=(16,8))
        sns.countplot(x=col,
                      data=data,
                      hue="Response",
                      palette='RdBu_r')

# %% [markdown]
# # Correlations between Features and Target

# %% [markdown]
# In order to quantify correlations between the features (variables) and the target, we can calculate the Pearson correlation coefficient. This is a measure of the strength and direction of a linear relationship between two variables: a value of -1 means the two variables are perfectly negatively linearly correlated and a value of +1 means the two variables are perfectly positively linearly correlated. The figure below shows different values of the correlation coeffient and how they appear graphically.

# %%
#calculate correlation
corr_matrix = data.corr('pearson') #kind of correlation->  ‘pearson’, ‘kendall’, ‘spearman’
#plot correlation
corr_matrix.style.background_gradient(cmap='coolwarm')
# 'RdBu_r', 'BrBG_r', & PuOr_r are other good diverging colormaps
# Out:
# <style type="text/css">
# #T_9fb7f_row0_col0, #T_9fb7f_row1_col1, #T_9fb7f_row2_col2, #T_9fb7f_row3_col3, #T_9fb7f_row4_col4, #T_9fb7f_row5_col5, #T_9fb7f_row6_col6, #T_9fb7f_row7_col7, #T_9fb7f_row8_col8, #T_9fb7f_row10_col10, #T_9fb7f_row11_col11, #T_9fb7f_row12_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_9fb7f_row0_col1, #T_9fb7f_row4_col10, #T_9fb7f_row5_col11 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_9fb7f_row0_col2, #T_9fb7f_row1_col8 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_9fb7f_row0_col3 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_9fb7f_row0_col4, #T_9fb7f_row4_col1, #T_9fb7f_row7_col4, #T_9fb7f_row10_col5, #T_9fb7f_row12_col4, #T_9fb7f_row12_col5 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_9fb7f_row0_col5, #T_9fb7f_row1_col0, #T_9fb7f_row3_col4, #T_9fb7f_row5_col6, #T_9fb7f_row7_col5, #T_9fb7f_row7_col6, #T_9fb7f_row8_col4, #T_9fb7f_row11_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_9fb7f_row0_col6, #T_9fb7f_row1_col7, #T_9fb7f_row1_col12, #T_9fb7f_row2_col1, #T_9fb7f_row2_col8, #T_9fb7f_row4_col3, #T_9fb7f_row4_col5, #T_9fb7f_row5_col4, #T_9fb7f_row6_col0, #T_9fb7f_row6_col3, #T_9fb7f_row8_col2, #T_9fb7f_row10_col11, #T_9fb7f_row11_col10, #T_9fb7f_row12_col1, #T_9fb7f_row12_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_9fb7f_row0_col7 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_9fb7f_row0_col8 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_9fb7f_row0_col9, #T_9fb7f_row1_col9, #T_9fb7f_row2_col9, #T_9fb7f_row2_col12, #T_9fb7f_row3_col9, #T_9fb7f_row4_col9, #T_9fb7f_row5_col9, #T_9fb7f_row6_col9, #T_9fb7f_row7_col9, #T_9fb7f_row8_col9, #T_9fb7f_row9_col0, #T_9fb7f_row9_col1, #T_9fb7f_row9_col2, #T_9fb7f_row9_col3, #T_9fb7f_row9_col4, #T_9fb7f_row9_col5, #T_9fb7f_row9_col6, #T_9fb7f_row9_col7, #T_9fb7f_row9_col8, #T_9fb7f_row9_col9, #T_9fb7f_row9_col10, #T_9fb7f_row9_col11, #T_9fb7f_row9_col12, #T_9fb7f_row10_col9, #T_9fb7f_row11_col9, #T_9fb7f_row12_col2, #T_9fb7f_row12_col9 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_9fb7f_row0_col10, #T_9fb7f_row3_col1, #T_9fb7f_row6_col10 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_9fb7f_row0_col11, #T_9fb7f_row3_col11, #T_9fb7f_row4_col12, #T_9fb7f_row5_col12, #T_9fb7f_row7_col12 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_9fb7f_row0_col12, #T_9fb7f_row2_col6, #T_9fb7f_row3_col5, #T_9fb7f_row4_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_9fb7f_row1_col2, #T_9fb7f_row12_col11 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_9fb7f_row1_col3, #T_9fb7f_row2_col3, #T_9fb7f_row2_col7, #T_9fb7f_row3_col7, #T_9fb7f_row6_col7 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_9fb7f_row1_col4, #T_9fb7f_row11_col7 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_9fb7f_row1_col5, #T_9fb7f_row4_col6, #T_9fb7f_row6_col5 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_9fb7f_row1_col6, #T_9fb7f_row5_col0, #T_9fb7f_row10_col0, #T_9fb7f_row10_col4, #T_9fb7f_row10_col6, #T_9fb7f_row11_col5 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_9fb7f_row1_col10, #T_9fb7f_row2_col0, #T_9fb7f_row2_col5, #T_9fb7f_row2_col11, #T_9fb7f_row11_col4 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_9fb7f_row1_col11 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_9fb7f_row2_col4, #T_9fb7f_row5_col7, #T_9fb7f_row7_col3, #T_9fb7f_row12_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_9fb7f_row2_col10, #T_9fb7f_row3_col12, #T_9fb7f_row6_col1, #T_9fb7f_row12_col10 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_9fb7f_row3_col0 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_9fb7f_row3_col2, #T_9fb7f_row8_col0, #T_9fb7f_row10_col8, #T_9fb7f_row11_col8 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_9fb7f_row3_col6, #T_9fb7f_row4_col7, #T_9fb7f_row8_col5, #T_9fb7f_row10_col7, #T_9fb7f_row12_col7 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_9fb7f_row3_col8 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_9fb7f_row3_col10, #T_9fb7f_row5_col10 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_9fb7f_row4_col2 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_9fb7f_row4_col8 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_9fb7f_row4_col11, #T_9fb7f_row6_col11, #T_9fb7f_row11_col12 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_9fb7f_row5_col1, #T_9fb7f_row6_col12 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_9fb7f_row5_col2 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_9fb7f_row5_col3, #T_9fb7f_row11_col3 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_9fb7f_row5_col8, #T_9fb7f_row6_col8, #T_9fb7f_row10_col2 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_9fb7f_row6_col2 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_9fb7f_row6_col4, #T_9fb7f_row10_col1 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_9fb7f_row7_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_9fb7f_row7_col1, #T_9fb7f_row10_col12, #T_9fb7f_row11_col6 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_9fb7f_row7_col2 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_9fb7f_row7_col8 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_9fb7f_row7_col10 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_9fb7f_row7_col11, #T_9fb7f_row8_col10, #T_9fb7f_row8_col11 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_9fb7f_row8_col1 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_9fb7f_row8_col3 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_9fb7f_row8_col6, #T_9fb7f_row8_col7, #T_9fb7f_row10_col3 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_9fb7f_row8_col12 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_9fb7f_row11_col1 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_9fb7f_row11_col2 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_9fb7f_row12_col6 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_9fb7f_row12_col8 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# </style>
# <table id="T_9fb7f_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Customer Lifetime Value</th>
#       <th class="col_heading level0 col1" >Response</th>
#       <th class="col_heading level0 col2" >Income</th>
#       <th class="col_heading level0 col3" >Monthly Premium Auto</th>
#       <th class="col_heading level0 col4" >Months Since Last Claim</th>
#       <th class="col_heading level0 col5" >Months Since Policy Inception</th>
#       <th class="col_heading level0 col6" >Number of Open Complaints</th>
#       <th class="col_heading level0 col7" >Number of Policies</th>
#       <th class="col_heading level0 col8" >Total Claim Amount</th>
#       <th class="col_heading level0 col9" >Year</th>
#       <th class="col_heading level0 col10" >Month</th>
#       <th class="col_heading level0 col11" >Day</th>
#       <th class="col_heading level0 col12" >Income_Anom</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9fb7f_level0_row0" class="row_heading level0 row0" >Customer Lifetime Value</th>
#       <td id="T_9fb7f_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_9fb7f_row0_col1" class="data row0 col1" >-0.002019</td>
#       <td id="T_9fb7f_row0_col2" class="data row0 col2" >0.025582</td>
#       <td id="T_9fb7f_row0_col3" class="data row0 col3" >0.359127</td>
#       <td id="T_9fb7f_row0_col4" class="data row0 col4" >0.010703</td>
#       <td id="T_9fb7f_row0_col5" class="data row0 col5" >-0.009442</td>
#       <td id="T_9fb7f_row0_col6" class="data row0 col6" >-0.042119</td>
#       <td id="T_9fb7f_row0_col7" class="data row0 col7" >0.126405</td>
#       <td id="T_9fb7f_row0_col8" class="data row0 col8" >0.156573</td>
#       <td id="T_9fb7f_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_9fb7f_row0_col10" class="data row0 col10" >-0.006408</td>
#       <td id="T_9fb7f_row0_col11" class="data row0 col11" >-0.002751</td>
#       <td id="T_9fb7f_row0_col12" class="data row0 col12" >-0.030660</td>
#     </

# %%
data['Pol_bins'] = pd.cut(data['Months Since Policy Inception'], bins = np.linspace(0, 120, num = 4))

# %%
data['Gender'] =pd.factorize(data['Gender'] )[0]

# %%
# function to obtain Categorical Features
def _get_categorical_features(df):
    feats = [col for col in list(df.columns) if df[col].dtype == 'object']
    return feats

dataC = data.copy()
data_cats = _get_categorical_features(data)
# generate binary values using get_dummies
data = pd.get_dummies(data , columns=data_cats )

# %%
data['Pol_bins']=pd.factorize(data['Pol_bins'])[0]
data['Income_Anom']=pd.factorize(data['Income_Anom'])[0]

# %%
data_labels =data['Response']

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer

# Drop the target from the  data
if 'Response' in data:
    data = data.drop(columns = ['Response'])
else:
    data = data.copy()
    
# Feature names
features = list(data.columns)



# Median imputation of missing values
imputer = SimpleImputer(strategy = 'median')

# Scale each feature to 0-1
scaler = MinMaxScaler(feature_range = (0, 1))

# Fit on the  data
imputer.fit(data)

# Transform data
data = imputer.transform(data)

# Repeat with the scaler
scaler.fit(data)
data = scaler.transform(data)

print('Data shape: ', data.shape)
# Out:
# Data shape:  (8600, 67)

# %%
# Separate out the features and targets
#features = dum_df.drop(columns='Response')
#targets = pd.DataFrame(dum_df['Response'])

# %%
# Split into 70% training and 30% testing set
X_train, X_test, y_train, y_test = train_test_split(data, data_labels, test_size = 0.3, random_state = 42)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (6020, 67)
# (2580, 67)
# (6020,)
# (2580,)

# %%
lr = LogisticRegression()
rfr = RandomForestClassifier(random_state=23)
dtr = tree.DecisionTreeClassifier()
class_svc = SVC()
xgbr = xgb.XGBClassifier()
lgbmr = lgb.LGBMClassifier()

estimators =[
             ('LogisticRegression',lr),
             ('RandomForestClassifier',rfr),
             ('DecisionTreeClassifier',dtr),
             ('SVC',class_svc),
             ('XGBMClassifier',xgbr),
             ('LGBMClassifier',lgbmr)
]

def model_training(X_train,X_test,y_train,y_test):
    
    for e,r in estimators:
        
        model_names = [e for e,r  in estimators]
        r.fit(X_train,y_train)
        r_preds = r.predict(X_test)
        print("*****************************************************")
        print('ROC_AUC_SCORE for {} is ==> '.format(e),roc_auc_score(y_test,r_preds))
        print('F1_SCORE for {} is ==> '.format(e),f1_score(y_test,r_preds))
        print('RECALL_SCORE for {} is ==> '.format(e),recall_score(y_test,r_preds))
        print("*****************************************************")
        print("\n")

model_training(X_train,X_test,y_train,y_test)
# Out:
# *****************************************************
# ROC_AUC_SCORE for LogisticRegression is ==>  0.5769996587603428
# F1_SCORE for LogisticRegression is ==>  0.26883910386965376
# RECALL_SCORE for LogisticRegression is ==>  0.16136919315403422
# *****************************************************
#
#
# *****************************************************
# ROC_AUC_SCORE for RandomForestClassifier is ==>  0.9756210730692084
# F1_SCORE for RandomForestClassifier is ==>  0.9701492537313432
# RECALL_SCORE for RandomForestClassifier is ==>  0.9535452322738386
# *****************************************************
#
#
# *****************************************************
# ROC_AUC_SCORE for DecisionTreeClassifier is ==>  0.9701122487017689
# F1_SCORE for DecisionTreeClassifier is ==>  0.8978675645342312
# RECALL_SCORE for DecisionTreeClassifier is ==>  0.9779951100244498
# *****************************************************
#
#
# *****************************************************
# ROC_AUC_SCORE for SVC is ==>  0.5864783504272253
# F1_SCORE for SVC is ==>  0.29554655870445345
# RECALL_SCORE for SVC is ==>  0.1784841075794621
# *****************************************************
#
#
# *****************************************************
# ROC_AUC_SCORE for XGBMClassifier is ==>  0.5871692762678518
# F1_SCORE for XGBMClassifier is ==>  0.2973523421588594
# RECALL_SCORE for XGBMClassifier is ==>  0.1784841075794621
# *****************************************************
#
#
# *****************************************************
# ROC_AUC_SCORE for LGBMClassifier is ==>  0.9869247774903456
# F1_SCORE for LGBMClassifier is ==>  0.9779951100244498
# RECALL_SCORE for LGBMClassifier is ==>  0.9779951100244498
# *****************************************************

# %%
 
dot_data = tree.export_graphviz(dtr, out_file=None)
graph = graphviz.Source(dot_data) 
graph.render("dtc-customer-churn")
# Out:
# 'dtc-customer-churn.pdf'

# %%
 #Takes in a model, trains the model, and evaluates the model on the test set
def fit_and_evaluate(model):
    
    # Train the model
    model.fit(X_train, y_train)
    
    # Make predictions and evalute
    model_pred = model.predict(X_test)
    model_roc = roc_auc_score(y_test, model_pred)
    
    # Return the performance metric
    return model_roc

# %%
lr_roc = fit_and_evaluate(lr)
print('LogisticRegression Performance : ROC = %0.4f' % lr_roc)


rfr_roc = fit_and_evaluate(rfr)
print('RandomForestClassifier Performance : ROC = %0.4f' % rfr_roc)

dtr_roc = fit_and_evaluate(dtr)
print('DecisionTreeClassifier Performance : ROC = %0.4f' % dtr_roc)

svc_roc = fit_and_evaluate(class_svc)
print('SVC Performance : ROC = %0.4f' % svc_roc)

xgbr_roc = fit_and_evaluate(xgbr)
print('XGBClassifier Performance : ROC = %0.4f' % xgbr_roc)

lgbmr_roc = fit_and_evaluate(lgbmr)
print('LGBMClassifier Performance : ROC = %0.4f' % lgbmr_roc)
# Out:
# LogisticRegression Performance : ROC = 0.5770
# RandomForestClassifier Performance : ROC = 0.9756
# DecisionTreeClassifier Performance : ROC = 0.9670
# SVC Performance : ROC = 0.5865
# XGBClassifier Performance : ROC = 0.5872
# LGBMClassifier Performance : ROC = 0.9869

# %%
plt.style.use('fivethirtyeight')
figsize(8, 6)

# Dataframe to hold the results
model_comparison = pd.DataFrame({'model': ['LogisticRegression', 'RandomForestClassifier',
                                           'DecisionTreeClassifier', 'SVC',
                                            'XGBClassifier','LGBMClassifier'],
                                 'roc': [lr_roc, rfr_roc, dtr_roc, 
                                         svc_roc, xgbr_roc,lgbmr_roc]})

# Horizontal bar chart 
model_comparison.sort_values('roc', ascending = False).plot(x = 'model', y = 'roc', kind = 'barh',
                                                           color = 'blue', edgecolor = 'black')

# Plot formatting
plt.ylabel(''); plt.yticks(size = 14); plt.xlabel('Receiver Operating Characteristic'); plt.xticks(size = 14)
plt.title('Model Comparison on Receiver Operating Characteristic (ROC)', size = 20);

# %% [markdown]
# *   A number of ensemble /tree algorithms seem to perform well.
#
#
# *   They might be overfitting .

# %% [markdown]
# #Addressing Imbalance on Target Features

# %%
# model tuning
#SMOTE
smt = SMOTE(random_state=15)
X_res, y_res = smt.fit_resample(data,data_labels)

# %%
# Split into 70% training and 30% testing set
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size = 0.3, random_state = 42)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (10318, 67)
# (4422, 67)
# (10318,)
# (4422,)

# %%
lr = LogisticRegression()
rfr = RandomForestClassifier(random_state=23)
dtr = tree.DecisionTreeClassifier()
class_svc = SVC()
xgbr = xgb.XGBClassifier()
lgbmr = lgb.LGBMClassifier()

estimators =[
             ('LogisticRegression',lr),
             ('RandomForestClassifier',rfr),
             ('DecisionTreeClassifier',dtr),
             ('SVC',class_svc),
             ('XGBMClassifier',xgbr),
             ('LGBMClassifier',lgbmr)
]

def model_training(X_train,X_test,y_train,y_test):
    
    for e,r in estimators:
        
        model_names = [e for e,r  in estimators]
        r.fit(X_train,y_train)
        r_preds = r.predict(X_test)
        print("*****************************************************")
        print('ROC_AUC_SCORE for {} is ==> '.format(e),roc_auc_score(y_test,r_preds))
        print('F1_SCORE for {} is ==> '.format(e),f1_score(y_test,r_preds))
        print('RECALL_SCORE for {} is ==> '.format(e),recall_score(y_test,r_preds))
        print("*****************************************************")
        print("\n")

model_training(X_train,X_test,y_train,y_test)
# Out:
# *****************************************************
# ROC_AUC_SCORE for LogisticRegression is ==>  0.7505762480259874
# F1_SCORE for LogisticRegression is ==>  0.7563507841837862
# RECALL_SCORE for LogisticRegression is ==>  0.7746606334841629
# *****************************************************
#
#
# *****************************************************
# ROC_AUC_SCORE for RandomForestClassifier is ==>  0.9771517759976435
# F1_SCORE for RandomForestClassifier is ==>  0.9767441860465117
# RECALL_SCORE for RandomForestClassifier is ==>  0.9597285067873303
# *****************************************************
#
#
# *****************************************************
# ROC_AUC_SCORE for DecisionTreeClassifier is ==>  0.9238002503825289
# F1_SCORE for DecisionTreeClassifier is ==>  0.9254259791989379
# RECALL_SCORE for DecisionTreeClassifier is ==>  0.9461538461538461
# *****************************************************
#
#
# *****************************************************
# ROC_AUC_SCORE for SVC is ==>  0.9617974356246881
# F1_SCORE for SVC is ==>  0.9630277838547364
# RECALL_SCORE for SVC is ==>  0.9959276018099548
# *****************************************************
#
#
# *****************************************************
# ROC_AUC_SCORE for XGBMClassifier is ==>  0.908154615302791
# F1_SCORE for XGBMClassifier is ==>  0.9012165450121655
# RECALL_SCORE for XGBMClassifier is ==>  0.8380090497737557
# *****************************************************
#
#
# *****************************************************
# ROC_AUC_SCORE for LGBMClassifier is ==>  0.9918601130812598
# F1_SCORE for LGBMClassifier is ==>  0.9918772563176895
# RECALL_SCORE for LGBMClassifier is ==>  0.9945701357466064
# *****************************************************

# %%
lr_roc = fit_and_evaluate(lr)
print('LogisticRegression Performance : ROC = %0.4f' % lr_roc)


rfr_roc = fit_and_evaluate(rfr)
print('RandomForestClassifier Performance : ROC = %0.4f' % rfr_roc)

dtr_roc = fit_and_evaluate(dtr)
print('DecisionTreeClassifier Performance : ROC = %0.4f' % dtr_roc)

svc_roc = fit_and_evaluate(class_svc)
print('SVC Performance : ROC = %0.4f' % svc_roc)

xgbr_roc = fit_and_evaluate(xgbr)
print('XGBClassifier Performance : ROC = %0.4f' % xgbr_roc)

lgbmr_roc = fit_and_evaluate(lgbmr)
print('LGBMClassifier Performance : ROC = %0.4f' % lgbmr_roc)
# Out:
# LogisticRegression Performance : ROC = 0.7506
# RandomForestClassifier Performance : ROC = 0.9772
# DecisionTreeClassifier Performance : ROC = 0.9258
# SVC Performance : ROC = 0.9618
# XGBClassifier Performance : ROC = 0.9082
# LGBMClassifier Performance : ROC = 0.9919

# %%
plt.style.use('fivethirtyeight')
figsize(8, 6)

# Dataframe to hold the results
model_comparison = pd.DataFrame({'model': ['LogisticRegression', 'RandomForestClassifier',
                                           'DecisionTreeClassifier', 'SVC',
                                            'XGBClassifier','LGBMClassifier'],
                                 'roc': [lr_roc, rfr_roc, dtr_roc, 
                                         svc_roc, xgbr_roc,lgbmr_roc]})

# Horizontal bar chart 
model_comparison.sort_values('roc', ascending = False).plot(x = 'model', y = 'roc', kind = 'barh',
                                                           color = 'blue', edgecolor = 'black')

# Plot formatting
plt.ylabel(''); plt.yticks(size = 14); plt.xlabel('Receiver Operating Characteristic'); plt.xticks(size = 14)
plt.title('Model Comparison on Receiver Operating Characteristic (ROC)', size = 20);

# %% [markdown]
# #Feature Importances

# %% [markdown]
# **Random Forest Classifier**

# %%
feat_importances = pd.Series(rfr.feature_importances_, index=features)
feat_importances.nlargest(10).plot(kind='barh')

# %% [markdown]
# **LightGBMClassifier**

# %%
feat_importances = pd.Series(lgbmr.feature_importances_, index=features)
feat_importances.nlargest(10).plot(kind='barh')

# %% [markdown]
# **Decision Tree Classifier**

# %%
feat_importances = pd.Series(dtr.feature_importances_, index=features)
feat_importances.nlargest(10).plot(kind='barh')

# %% [markdown]
# **XGBoost Classifier**

# %%
feat_importances = pd.Series(xgbr.feature_importances_, index=features)
feat_importances.nlargest(10).plot(kind='barh')

# %%
import pickle
#save the lightgbmmodel 
pickle.dump(lgbmr, open("lgbmr_model.sav", "wb"))
pickle.dump(xgbr, open("xgbr_model.sav", "wb"))
pickle.dump(dtr, open("dtr_model.sav", "wb"))
pickle.dump(rfr, open("rfr_model.sav", "wb"))
pickle.dump(class_svc, open("svc_model.sav", "wb"))
